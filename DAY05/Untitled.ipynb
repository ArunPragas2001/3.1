# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2

# %%
img1=cv2.imread("picture1.jpg",cv2.IMREAD_GRAYSCALE).astype(np.float32)
img2=cv2.imread("picture2.jpg",cv2.IMREAD_GRAYSCALE).astype(np.float32)

# %%
print(img1.shape)
print(img2.shape)
# Out:
# (5504, 5504)
# (3859, 5788)

# %%
#if two images are not same in shape. matching one image1 with image2
if img1.shape!=img2.shape:
    height=img1.shape[0]
    width=img1.shape[1]
    img2=cv2.resize(img2,(width,height))
    print ("resized image2 to match image1 shape",img2.shape)
# Out:
# resized image2 to match image1 shape (5504, 5504)

# %%
print(img1.shape)
print(img2.shape)
# Out:
# (5504, 5504)
# (5504, 5504)

# %%
plt.figure(figsize=(6,5))
plt.imshow(img1, cmap="gray")
plt.title=("Original gray scale image")
plt.axis("off")
plt.show()


plt.figure(figsize=(6,5))
plt.imshow(img2, cmap="gray")
plt.title=("Original gray scale image")
plt.axis("off")
plt.show()

# %%
added=img1+img2
added=np.clip(added ,0,255)
added=added.astype(np.uint8)

# %%
#opencv addition 
img1_n=cv2.imread("picture1.jpg",cv2.IMREAD_GRAYSCALE)
img2_n=cv2.imread("picture2.jpg",cv2.IMREAD_GRAYSCALE)

if img1_n.shape!=img2_n.shape:
    height=img1_n.shape[0]
    width=img1_n.shape[1]
    img2_n=cv2.resize(img2_n,(width,height))
    print ("resized image2 to match image1 shape",img2_n.shape)
# Out:
# resized image2 to match image1 shape (5504, 5504)

# %%
added_cv2=cv2.add(img1_n,img2_n)
subtracted_cv2=cv2.subtract(img1_n,img2_n)

# %%
averaged=(img1+img2)/2
averaged=averaged.astype(np.uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.imshow(added_cv2,cmap="gray")
#plt.title("Manual addition(np.clip)")
plt.axis("off")
plt.show()


plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.imshow(subtracted_cv2,cmap="gray")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
#weighted blending(alpha bending)
#RESULT=alpha * img1+(1-alpha) * img2
alpha=0.7
blended=alpha* img1 + (1-alpha)*img2
blended=np.clip(blended,0,255)
blended=blended.astype(np.uint8)

# %%
blended_cv2=cv2.addWeighted(img1_n,alpha,img2_n,1-alpha,0)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(blended,cmap="gray")
plt.title(f"Manual blend (alpha:{alpha})")
plt.axis("off")
plt.show()

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(blended_cv2,cmap="gray")
plt.title(f"cv2.addWeighted blend")
plt.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9520\1373454189.py in <module>
#       2 plt.subplot(1,2,1)
#       3 plt.imshow(blended,cmap="gray")
# ----> 4 plt.title(f"Manual blend (alpha:{alpha})")
#       5 plt.axis("off")
#       6 plt.show()
#
# TypeError: 'str' object is not callable

# %%
#masking operations
mask= np.zeros(img1.shape,dtype=np.uint8)
h=mask.shape[0]
w=mask.shape[1]
mask[h//4:3*h//4:3*w//4]=255

# %%
plt.figure(figsize=(6,5))
plt.imshow(mask,cmap='gray')
plt.title("Binary Mask")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9520\2972013466.py in <module>
#       1 plt.figure(figsize=(6,5))
#       2 plt.imshow(mask,cmap='gray')
# ----> 3 plt.title("Binary Mask")
#       4 plt.axis("off")
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
masked_region=cv2.bitwise_and(img1_n,img1_n,mask=mask)

# %%
plt.figure(figsize=(6,5))
plt.imshow(masked_region,cmap='gray')
plt.title("Image and Mask(ROI kept)")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9520\172976520.py in <module>
#       1 plt.figure(figsize=(6,5))
#       2 plt.imshow(masked_region,cmap='gray')
# ----> 3 plt.title("Image and Mask(ROI kept)")
#       4 plt.axis("off")
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
inverted_mask=cv2.bitwise_not(mask)
masked_region_inverse=cv2.bitwise_and(img1_n,img1_n,mask=inverted_mask)

# %%
plt.figure(figsize=(6,5))
plt.imshow(masked_region_inverse,cmap='gray')
plt.title("Image and Mask(ROI kept)")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9520\611005186.py in <module>
#       1 plt.figure(figsize=(6,5))
#       2 plt.imshow(masked_region_inverse,cmap='gray')
# ----> 3 plt.title("Image and Mask(ROI kept)")
#       4 plt.axis("off")
#       5 plt.show()
#
# TypeError: 'str' object is not callable
